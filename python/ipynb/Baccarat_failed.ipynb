# %%
import random


"""
Users
"""
class User :

    win_count = 0
    lose_count = 0 
    
    def __init__(self, capital) :
        self.capital = capital
    
player = User(100*10000)
banker=User(1000*10000)

# %%
class counter :
    
    def pl_counting(self, deck) :
        
        self.deck_sum = sum(deck)%10
        
        if self.deck_sum <= 5 : 
            print("One more card!")
            self.deck.append(random.ranrange(1, 14))
    
        elif (self.deck_sum == 6) | (self.deck_sum==7) :
            print("Stand!")
        
        else : 
            print("Natural!")
        
        self.deck_sum = sum(deck)%10
        
        return self.deck_sum

    
    def ba_counting(self, pl_deck, ba_deck) :
        
        if len(self.pl_deck) == 3
        
            self.deck_sum = sum(ba_deck)%10

            if self.deck_sum <= 2 : 
                print("One more card!")
                self.deck.append(random.ranrange(1, 14))

            elif (self.deck_sum == 3) & (self.pl_deck[2] != 8) :
                print("One more card!")
                self.deck.append(random.ranrange(1, 14))
                
            elif (self.deck_sum == 4) & (self.pl_deck[2] in range(2,8)) :
                print("One more card!")
                self.deck.append(random.ranrange(1, 14))
            
            elif (self.deck_sum == 5) & (self.pl_deck[2] in range(4,8)) :
                print("One more card!")
                self.deck.append(random.ranrange(1, 14))
                
            elif (self.deck_sum == 6) & (self.pl_deck[2] in range(6,8)) :
                print("One more card!")
                self.deck.append(random.ranrange(1, 14))
            
            elif (self.deck_sum == 7) :
                print("Stand!")

            else :  
                print("Natural!")
                
        self.deck_sum = sum(deck)%10

        return self.deck_sum
    
"""
tie, pair 도 세야함. -> card_status 
score에 반영 
"""
# Out:
# 1000000

# %%
class score(baccarat, counter) :
    
    def __init(self, pl_deck, ba_deck) :
        score_table = {
            'pl_score' : super().pl_counting(self.pl_deck)[0],
            'pl_status' : super().pl_counting(self.pl_deck)[1],

            'ba_score' : super().ba_counting(self.ba_deck)[0],
            'ba_status' : super().bl_counting(self.ba_deck)[1],
        }

        return score_table

    def winner(self, score_table) :
        
        winner = ''
        
        #bet
        if score_table['pl_score'] > score_table['ba_score'] :
            winner = 'player'
            
        elif score_table['pl_score'] < score_table['ba_score'] :
            winner = 'banker'
         
        #side-bet
        if score_table['pl_score'] == score_table['ba_score'] :
            
            if (baccarat.pl_side_bet == 'tie') | (baccarat.pl_side_bet == 1) :
                side_winner = 'player'
            elif baccarat.ba_side_bet == 1 :
                side_winner = 'banker'
            
        elif score_table['pl_score'] == score_table['ba_score'] : #같은 수가 2개 
                
            if (baccarat.pl_side_bet == 'pair') | (baccarat.pl_side_bet == 2) :
                side_winner = 'player'
            elif baccarat.ba_side_bet == 2 :
                side_winner = 'banker' 
        
        return winner, side_winner 
    
    def reward(self, winner) :
        
        if winner == 'player' : 
            player.capital += (baccarat.pl_bet_money*2)
        elif winner == 'banker' :
            banker.capital += (baccarat.ba_bet_money*1.95)
        
        if side_winner == 'player' :
            player.capital += baccarat.pl_side_bet_money*8
        elif side_winner == 'banker' :
            player.capital += baccarat.pl_side_bet_money*8
# Out:
# [3, 2]

# %%
class baccarat(score) : 

    def betting(self) :
        
        #Player's betting
        print("Your Capital : %d\n" %player.capital,
              "Please bet your money(>= 5000) \n> ")
        
        self.pl_bet_money = int(input(""))
        
        player.capital -= self.pl_bet_money
        
        #Player's side-bet
        print("Do you want to side-bet? y/n")
        self.pl_answer = input("")
        
        if self.pl_answer == 'y' : 
           cl print("[1. Tie(8 to 1) | 2. Pair(11 to 1)]\n",
                  "-------------------------------------------\n",
                  "Your Capital : %d\n" %(player.capital),
                  "Please bet your money (ex. 1, 5000)")

            self.pl_input = input("")
            self.pl_input = self.pl_input.split(",") if ',' in self.pl_input else self.pl_input.split()

            self.pl_side_bet = self.pl_input[0].lowercase() #Type : str # 1,2 또는 tie, Tie, pair, Pair
            self.pl_side_bet_money = int(self.pl_input[1]) # 자본금 이상 베팅 못하게. 
            
        else : 
            self.pl_side_bet = 0  
            self.pl_side_bet_money = 0
            
            
        #Banker's betting 
        self.ba_bet_money = random.randrange(5000,round(banker.capital/5), 5000)
        banker.capital -= self.ba_bet_money
        
        #Banker's side-bet
        self.ba_side_bet = random.randrange(1,3)
        self.ba_side_bet_money = random.randrange(0,round((banker.capital)/10), 5000)
                
        return self.pl_bet_money, self.pl_side_bet, self.pl_side_bet_money, self.ba_bet_money, self.ba_side_bet, self.ba_side_bet_money
    
    def dealing(self) :
        
        #print("-------------------------------------------\n","Dealing Start") #함수 밖에서 정의해야 할 듯. 
        
        #2 cards
        self.deck = random.sample(range(1,14), 2) 
        
        for i in range(len(self.deck)) :
            if self.deck[i] >= 10 :
                self.deck[i] = 0

        return self.deck
    
    def 
        
        

pl_game = player_baccarat()

# %%
test['a']
# Out:
# [1, 2, 3]

# %%
        self.bet_table = {'player' : 0,
                          'player_pair' : 0, 
                          'banker' : 0,
                          'banker_pair' : 0,
                          'tie' : 0,} 
    
    
class User :
    
    def __init__(self, seed_money) :
        self.seed_money = seed_money
        self.grade = 'Bronze'
        self.record = {'win' : 0, 'lose' : 0, 'pair' : 0, 'tie' : 0 }
        self.score = (self.record['win']*100 + 
                     self.record['pair']*1000 +
                     self.record['tie']*500) 
        
    def grade(self) :
        if self.score <= 5000 :
            self.grade = 'Bronze'
        elif self.score <= 10000 : 
            self.grade = 'Platinum'
        elif self.score <= 25000 : 
            self.grade = 'Diamond'
        elif self.score <= 50000 : 
            self.grade = 'Master'
        elif self.score > 50000 : 
            self.grade = 'Grand Master'
            
        return self.grade
